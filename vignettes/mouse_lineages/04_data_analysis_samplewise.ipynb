# %%
import warnings
warnings.filterwarnings(
    action='ignore',
    category=FutureWarning
)

# %%
import FACSPy as fp

# %%
dataset = fp.read_dataset(input_dir = "../../Tutorials/mouse_lineages",
                          file_name = "raw_dataset_gated")

# %%
fp.settings.default_gate = "CD45+"
fp.settings.default_layer = "transformed"

# %%
### we calculate the gate frequencies

fp.tl.gate_frequencies(dataset)

# %%
fp.tl.mfi(dataset,
          layer = "compensated")
fp.tl.mfi(dataset,
          layer = "transformed")
fp.pl.sample_correlation(dataset,
                         annotate = ["genotype", "organ"], 
                         cmap = "inferno")

# %%
### we subset the bone marrow cells and make a copy
bm_subset = dataset[dataset.obs["organ"] == "BM",:].copy()
fp.sync.synchronize_dataset(bm_subset)
# Out:
# ['obs_names']
#      ... synchronized frame mfi_CD45+_transformed_leiden_compensated
#      ... updated metadata

# %%
fp.tl.mfi(bm_subset,
          layer = "compensated")

# %%
fp.tl.fop(bm_subset,
          layer = "compensated")

# %%
for cell_type in ["Neutrophils", "B_cells", "T_cells", "CD4_T_cells", "CD8_T_cells", "NK_cells", "Monocytes"]:
    fp.pl.gate_frequency(bm_subset,
                         gate = cell_type,
                         freq_of = "parent",
                         groupby = "genotype",
                         colorby = "genotype")

# %%
fp.pl.mfi(bm_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6G")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "B_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "B220")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(bm_subset,
          gate = "NK_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "NK1.1")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
### we subset the bone marrow cells and make a copy
pb_subset = dataset[dataset.obs["organ"] == "PB",:].copy()
fp.sync.synchronize_dataset(pb_subset)
# Out:
# ['obs_names']
#      ... synchronized frame mfi_CD45+_transformed_leiden_compensated
#      ... updated metadata

# %%
fp.tl.mfi(pb_subset,
          layer = "compensated")

# %%
fp.tl.fop(pb_subset,
          layer = "compensated")

# %%
for cell_type in ["Neutrophils", "B_cells", "T_cells", "CD4_T_cells", "CD8_T_cells", "NK_cells", "Monocytes"]:
    fp.pl.gate_frequency(pb_subset,
                         gate = cell_type,
                         freq_of = "parent",
                         groupby = "genotype",
                         colorby = "genotype")

# %%
fp.pl.mfi(pb_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6G")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "B_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "B220")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(pb_subset,
          gate = "NK_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "NK1.1")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
### we subset the bone marrow cells and make a copy
spl_subset = dataset[dataset.obs["organ"] == "SPL",:].copy()
fp.sync.synchronize_dataset(spl_subset)
# Out:
# ['obs_names']
#      ... synchronized frame mfi_CD45+_transformed_leiden_compensated
#      ... updated metadata

# %%
fp.tl.mfi(spl_subset,
          layer = "compensated")

# %%
fp.tl.fop(spl_subset,
          layer = "compensated")

# %%
for cell_type in ["Neutrophils", "B_cells", "T_cells", "CD4_T_cells", "CD8_T_cells", "NK_cells", "Monocytes"]:
    fp.pl.gate_frequency(spl_subset,
                         gate = cell_type,
                         freq_of = "parent",
                         groupby = "genotype",
                         colorby = "genotype")

# %%
fp.pl.mfi(spl_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6G")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "Neutrophils",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "Ly6C")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "Monocytes",
          layer = "compensated",
          groupby = "genotype",
          marker = "CD11b")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "B_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "B220")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.mfi(spl_subset,
          gate = "NK_cells",
          layer = "compensated",
          groupby = "genotype",
          marker = "NK1.1")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.save_dataset(dataset,
                output_dir = "../../Tutorials/mouse_lineages",
                file_name = "raw_dataset_samplewise",
                overwrite = True)
# Out:
# File saved successfully
