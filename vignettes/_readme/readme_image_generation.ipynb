# %%
import warnings
warnings.filterwarnings(
    action='ignore',
    category=FutureWarning
)

# %%
import FACSPy as fp
from matplotlib import pyplot as plt

# %%
fp.settings.tight_layout = False

# %%
output_dir = "../../FACSPy/img/"

# %%
metadata = fp.dt.Metadata("../../Tutorials/spectral_dataset/metadata.csv")
panel = fp.dt.Panel("../../Tutorials/spectral_dataset/panel.txt")
workspace = fp.dt.FlowJoWorkspace("../../Tutorials/spectral_dataset/FD_NK.wsp")

dataset = fp.create_dataset(input_directory = "../../Tutorials/spectral_dataset/",
                            panel = panel,
                            metadata = metadata,
                            workspace = workspace,
                            subsample_fcs_to = None,
                            keep_raw = False)
# Out:
# ... gating sample 3742.fcs
# ... gating sample 4337.fcs
# ... gating sample 4449.fcs
# ... gating sample 5143.fcs
# ... gating sample 6042.fcs
# ... gating sample 6840.fcs
# ... gating sample DO1.fcs
# ... gating sample DO2.fcs
# ... gating sample DO3.fcs
# ... gating sample DO4.fcs
# ... gating sample DO5.fcs
# ... gating sample DO6.fcs
# ... gating sample DO7.fcs
# ... gating sample DO8.fcs
# ... gating sample DO9.fcs
# ... gating sample DO10.fcs
# ... gating sample DO11.fcs
# ... gating sample DO12.fcs
# ... gating sample DO13.fcs
# ... gating sample DO14.fcs
# ... gating sample DO15.fcs
# ... gating sample DO16.fcs
# ... gating sample DO17.fcs
# ... gating sample DO18.fcs
# ... gating sample DO19.fcs
# ... gating sample DO20.fcs
# ... gating sample DO21.fcs
# ... gating sample DO22.fcs
# ... gating sample DO23.fcs
# ... gating sample DO24.fcs
# ... gating sample DO25.fcs
# ... gating sample DO26.fcs
# ... gating sample DO27.fcs
# ... gating sample 2306.fcs
# ... gating sample 4212.fcs
# ... gating sample 6252.fcs
# ... compensating sample 3742.fcs
# ... compensating sample 4337.fcs
# ... compensating sample 4449.fcs
# ... compensating sample 5143.fcs
# ... compensating sample 6042.fcs
# ... compensating sample 6840.fcs
# ... compensating sample DO1.fcs
# ... compensating sample DO2.fcs
# ... compensating sample DO3.fcs
# ... compensating sample DO4.fcs
# ... compensating sample DO5.fcs
# ... compensating sample DO6.fcs
# ... compensating sample DO7.fcs
# ... compensating sample DO8.fcs
# ... compensating sample DO9.fcs
# ... compensating sample DO10.fcs
# ... compensating sample DO11.fcs
# ... compensating sample DO12.fcs
# ... compensating sample DO13.fcs
# ... compensating sample DO14.fcs
# ... compensating sample DO15.fcs
# ... compensating sample DO16.fcs
# ... compensating sample DO17.fcs
# ... compensating sample DO18.fcs
# ... compensating sample DO19.fcs
# ... compensating sample DO20.fcs
# ... compensating sample DO21.fcs
# ... compensating sample DO22.fcs
# ... compensating sample DO23.fcs
# ... compensating sample DO24.fcs
# ... compensating sample DO25.fcs
# ... compensating sample DO26.fcs
# ... compensating sample DO27.fcs
# ... compensating sample 2306.fcs
# ... compensating sample 4212.fcs
# ... compensating sample 6252.fcs
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# ...
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BUV496-A. FCS data documented NKG2C while the user supplied panel documented NKG2C_(CD159c). The antigen will be referenced as described from the user supplied panel: NKG2C_(CD159c)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel BV421-A. FCS data documented 41BB while the user supplied panel documented 41BB_(CD137). The antigen will be referenced as described from the user supplied panel: 41BB_(CD137)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-A. FCS data documented NKG2A while the user supplied panel documented NKG2A_(CD159a). The antigen will be referenced as described from the user supplied panel: NKG2A_(CD159a)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Dazzle594-A. FCS data documented CTLA_4 while the user supplied panel documented CTLA-4_(CD152). The antigen will be referenced as described from the user supplied panel: CTLA-4_(CD152)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel PE-Cy7-A. FCS data documented TRAIL while the user supplied panel documented TRAIL_(CD253). The antigen will be referenced as described from the user supplied panel: TRAIL_(CD253)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Alexa Fluor 647-A. FCS data documented PD_1 while the user supplied panel documented PD-1_(CD279) . The antigen will be referenced as described from the user supplied panel: PD-1_(CD279)
#   warnings.warn(message, UserWarning)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\exceptions\_supplements.py:15: UserWarning: Antigens do not match for channel Zombie NIR-A. FCS data documented Z_NIR while the user supplied panel documented Zombie_NIR. The antigen will be referenced as described from the user supplied panel: Zombie_NIR
#   warnings.warn(message, UserWarning)

# %%
fp.dt.calculate_cofactors(dataset)
# Out:
# ... calculating cofactors
#     ... sample 3742.fcs
#     ... sample 4337.fcs
#     ... sample 4449.fcs
#     ... sample 5143.fcs
#     ... sample 6042.fcs
#     ... sample 6840.fcs
#     ... sample DO1.fcs
#     ... sample DO2.fcs
#     ... sample DO3.fcs
#     ... sample DO4.fcs
#     ... sample DO5.fcs
#     ... sample DO6.fcs
#     ... sample DO7.fcs
#     ... sample DO8.fcs
#     ... sample DO9.fcs
#     ... sample DO10.fcs
#     ... sample DO11.fcs
#     ... sample DO12.fcs
#     ... sample DO13.fcs
#     ... sample DO14.fcs
#     ... sample DO15.fcs
#     ... sample DO16.fcs
#     ... sample DO17.fcs
#     ... sample DO18.fcs
#     ... sample DO19.fcs
#     ... sample DO20.fcs
#     ... sample DO21.fcs
#     ... sample DO22.fcs
#     ... sample DO23.fcs
#     ... sample DO24.fcs
#     ... sample DO25.fcs
#     ... sample DO26.fcs
#     ... sample DO27.fcs
#     ... sample 2306.fcs
#     ... sample 4212.fcs
#     ... sample 6252.fcs

# %%
### the calculated cofactors are saved in the dataset and can be extracted
calculated_cofactors = dataset.uns["cofactors"]

calculated_cofactors
# Out:
# CofactorTable(28 channels, loaded as provided dataframe)

# %%
### if you have a table of your own cofactors you can load them:
supplied_cofactors = fp.dt.CofactorTable("../../Tutorials/spectral_dataset/cofactors.txt")

supplied_cofactors
# Out:
# CofactorTable(28 channels, loaded as provided file)

# %%
fp.dt.transform(dataset,
                transform = "asinh",
                cofactor_table = supplied_cofactors,
                key_added = "transformed",
                layer = "compensated")

# %%
fp.pl.transformation_plot(dataset,
                          sample_identifier = "2",
                          marker = "CD3",
                          show = True,
                          save = f"{output_dir}transformation_plot.png")

#plt.savefig("../FACSPy/img/transformation_plot.png", bbox_inches = "tight", dpi = 300)
#plt.show()

# %%
fp.pl.biax(dataset,
           gate = "CD45+",
           x_channel = "CD3",
           y_channel = "SSC-A",
           sample_identifier = "3",
           color = "density",
           title = "Color: Density",
           figsize = (5,4),
           save = f"{output_dir}biax_density.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\plotting\_biax.py:246: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(**plot_params,

# %%
fp.pl.biax(dataset,
           gate = "CD45+",
           x_channel = "CD3",
           y_channel = "SSC-A",
           sample_identifier = "3",
           color = "CD4",
           figsize = (5,4),
           vmin = 1,
           vmax = 4e4,
           title = "Color: CD4",
           save = f"{output_dir}biax_CD4.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\plotting\_biax.py:246: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(**plot_params,

# %%
fp.pl.biax(dataset,
           gate = "CD45+",
           x_channel = "CD3",
           y_channel = "SSC-A",
           sample_identifier = "3",
           color = "CD8",
           cmap = "viridis",
           vmin = 1,
           vmax = 4e4,
           figsize = (5,4),
           title = "Color: CD8",
           save = f"{output_dir}biax_CD8.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\plotting\_biax.py:246: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(**plot_params,

# %%
### first, we plot the cell counts
fp.pl.cell_counts(dataset,
                  gate = "live",
                  groupby = "diag_main",
                  figsize = (2,4),
                  save = f"{output_dir}cell_counts.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
### first, we plot the cell counts
fp.pl.cell_counts(dataset,
                  gate = "live",
                  groupby = "diag_main",
                  splitby = "organ",
                  stat_test = False,
                  figsize = (2,4),
                  save = f"{output_dir}cell_counts_split.png")

# %%
### we calculate the gate frequencies
fp.tl.gate_frequencies(dataset)

# %%
fp.pl.gate_frequency(dataset,
                     gate = "CD45+",
                     groupby = "diag_main",
                     freq_of = "parent",
                     figsize = (2,4),
                     save = f"{output_dir}gate_frequency.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.gate_frequency(dataset,
                     gate = "CD45+",
                     groupby = "diag_main",
                     splitby = "organ",
                     freq_of = "parent",
                     stat_test = False,
                     figsize = (2,4),
                     save = f"{output_dir}gate_frequency_split.png")

# %%
fp.subset_gate(dataset,
               gate = "CD45+",
               copy = False)
fp.sync.synchronize_dataset(dataset)
# Out:
# ['obs_names']
#      ... updated metadata

# %%
import scanpy as sc
sc.pp.subsample(dataset,
                n_obs = 100_000,
                random_state = 187)

# %%
fp.settings.default_layer = "transformed"
fp.settings.default_gate = "CD45+"

# %%
fp.tl.pca(dataset,
          gate = "CD45+", # unnecessary here as it has been set above
          layer = "transformed", # unnecessary here as it has been set above
          use_only_fluo = True, # whether to use only fluorescence channels, default = True
          exclude = None, # list of channels to exclude for analysis
          scaling = None # whether to apply scaling
          )
fp.tl.neighbors(dataset,
                gate = "CD45+", # unnecessary here as it has been set above
                layer = "transformed", # unnecessary here as it has been set above
                use_only_fluo = True, # whether to use only fluorescence channels, default = True
                exclude = None, # list of channels to exclude for analysis
                scaling = None # whether to apply scaling
                )
fp.tl.leiden(dataset,
             gate = "CD45+", # unnecessary here as it has been set above
             layer = "transformed", # unnecessary here as it has been set above
             use_only_fluo = True, # whether to use only fluorescence channels, default = True
             exclude = None, # list of channels to exclude for analysis
             scaling = None # whether to apply scaling
             )
fp.tl.umap(dataset,
           gate = "CD45+", # unnecessary here as it has been set above
           layer = "transformed", # unnecessary here as it has been set above
           use_only_fluo = True, # whether to use only fluorescence channels, default = True
           exclude = None, # list of channels to exclude for analysis
           scaling = None # whether to apply scaling
           )
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\pynndescent\pynndescent_.py:346: NumbaPendingDeprecationWarning: Code using Numba extension API maybe depending on 'old_style' error-capturing, which is deprecated and will be replaced by 'new_style' in a future release. See details at https://numba.readthedocs.io/en/latest/reference/deprecation.html#deprecation-of-old-style-numba-captured-errors
# Exception origin:
#   File "C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\numba\core\types\functions.py", line 486, in __getnewargs__
#     raise ReferenceError("underlying object has vanished")
#
#   init_rp_tree(data, dist, current_graph, leaf_array)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\pynndescent\pynndescent_.py:348: NumbaPendingDeprecationWarning: Code using Numba extension API maybe depending on 'old_style' error-capturing, which is deprecated and will be replaced by 'new_style' in a future release. See details at https://numba.readthedocs.io/en/latest/reference/deprecation.html#deprecation-of-old-style-numba-captured-errors
# Exception origin:
#   File "C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\numba\core\types\functions.py", line 486, in __getnewargs__
#     raise ReferenceError("underlying object has vanished")
#
#   init_random(n_neighbors, data, current_graph, dist, rng_state)
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\pynndescent\pynndescent_.py:358: NumbaPendingDeprecationWarning: Code using Numba extension API maybe depending on 'old_style' error-capturing, which is deprecated and will be replaced by 'new_style' in a future release. See details at https://numba.readthedocs.io/en/latest/reference/deprecation.html#deprecation-of-old-style-numba-captured-errors
# Exception origin:
#   File "C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\numba\core\types\functions.py", line 486, in __getnewargs__
#     raise ReferenceError("underlying object has vanished")
#
#   nn_descent_internal_low_memory_parallel(

# %%
fp.pl.umap(dataset, color = "CD3", vmin = 0, vmax = 4, save = f"{output_dir}CD3_umap.png")

# %%
fp.pl.umap(dataset, color = "CD4", vmin = 0, vmax = 4, save = f"{output_dir}CD4_umap.png")

# %%
fp.pl.umap(dataset, color = "CD8", vmin = 0, vmax = 4, save = f"{output_dir}CD8_umap.png")

# %%
fp.pl.umap(dataset, color = "CD16", vmin = 0, vmax = 4, save = f"{output_dir}CD16_umap.png")

# %%
fp.pl.umap(dataset, color = "CD56", vmin = 0, vmax = 4, save = f"{output_dir}CD56_umap.png")

# %%
fp.pl.umap(dataset,
           color = "CD45+_transformed_leiden",
           vmin = 0, vmax = 4,
           legend_loc = "on data",
           figsize = (4,4),
           save = f"{output_dir}leiden_umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.convert_cluster_to_gate(dataset,
                           obs_column = "CD45+_transformed_leiden",
                           positive_cluster = ["10", "17", "2"],
                           population_name = "NK_cells",
                           parent_name = "CD45+")
fp.convert_gate_to_obs(dataset,
                       "NK_cells")

# %%
fp.pl.umap(dataset, color = "NK_cells", vmin = 0, vmax = 4, figsize = (3,3), save = f"{output_dir}NK_cell_umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
gating_strategy = {
    "T_cells": ["CD45+", ["CD3+", "CD45+"]],
    "CD4_T_cells": ["T_cells", ["CD3+", "CD4+", "CD8-", "CD45+"]],
    "CD8_T_cells": ["T_cells", ["CD3+", "CD4-", "CD8+", "CD45+"]]
}

# %%
clf = fp.ml.unsupervisedGating(dataset,
                               gating_strategy = gating_strategy,
                               clustering_algorithm = "leiden", 
                               layer = "transformed",
                               cluster_key = None)

# %%
clf.identify_populations()
# Out:
# Analyzing population: T_cells
# Analyzing population: CD45+
# ... sample 6840.fcs
#      ... gating population T_cells
# ... sample 3742.fcs
#      ... gating population T_cells
# ... sample 5143.fcs
#      ... gating population T_cells
# ... sample DO9.fcs
#      ... gating population T_cells
# ... sample DO26.fcs
#      ... gating population T_cells
# ... sample DO6.fcs
#      ... gating population T_cells
# ... sample 6252.fcs
#      ... gating population T_cells
# ... sample DO15.fcs
#      ... gating population T_cells
# ... sample 4337.fcs
#      ... gating population T_cells
# ... sample DO16.fcs
#      ... gating population T_cells
# ... sample 2306.fcs
#      ... gating population T_cells
# ... sample DO12.fcs
#      ... gating population T_cells
# ... sample DO10.fcs
#      ... gating population T_cells
# ... sample DO17.fcs
#      ... gating population T_cells
# ... sample DO27.fcs
#      ... gating population T_cells
# ... sample DO20.fcs
#      ... gating population T_cells
# ... sample DO25.fcs
#      ... gating population T_cells
# ... sample 6042.fcs
#      ... gating population T_cells
# ... sample 4449.fcs
#      ... gating population T_cells
# ... sample 4212.fcs
#      ... gating population T_cells
# ... sample DO13.fcs
#      ... gating population T_cells
# ... sample DO8.fcs
#      ... gating population T_cells
# ... sample DO5.fcs
#      ... gating population T_cells
# ... sample DO11.fcs
#      ... gating population T_cells
# ... sample DO14.fcs
#      ... gating population T_cells
# ... sample DO24.fcs
#      ... gating population T_cells
# ... sample DO21.fcs
#      ... gating population T_cells
# ... sample DO22.fcs
#      ... gating population T_cells
# ... sample DO7.fcs
#      ... gating population T_cells
# ... sample DO1.fcs
#      ... gating population T_cells
# ... sample DO18.fcs
#      ... gating population T_cells
# ... sample DO19.fcs
#      ... gating population T_cells
# ... sample DO4.fcs
#      ... gating population T_cells
# ... sample DO23.fcs
#      ... gating population T_cells
# ... sample DO3.fcs
#      ... gating population T_cells
# ... sample DO2.fcs
#      ... gating population T_cells
# ... sample 6840.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 3742.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 5143.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO9.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO26.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO6.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 6252.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO15.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 4337.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO16.fcs
# computing PCA for leiden
# computing neighbors for leiden!
# WARNING: n_obs too small: adjusting to `n_neighbors = 5`
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 2306.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO12.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO10.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO17.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO27.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO20.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO25.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 6042.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 4449.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample 4212.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO13.fcs
# computing PCA for leiden
# computing neighbors for leiden!
# WARNING: n_obs too small: adjusting to `n_neighbors = 4`
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO8.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO5.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO11.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO14.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO24.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO21.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO22.fcs
# computing PCA for leiden
# computing neighbors for leiden!
# WARNING: n_obs too small: adjusting to `n_neighbors = 4`
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO7.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO1.fcs
# computing PCA for leiden
# computing neighbors for leiden!
# WARNING: n_obs too small: adjusting to `n_neighbors = 2`
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO18.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO19.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO4.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO23.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO3.fcs
# computing PCA for leiden
# computing neighbors for leiden!
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells
# ... sample DO2.fcs
# computing PCA for leiden
# computing neighbors for leiden!
# WARNING: n_obs too small: adjusting to `n_neighbors = 8`
#      ... gating population CD4_T_cells
#      ... gating population CD8_T_cells

# %%
fp.convert_gate_to_obs(dataset, "T_cells")
fp.convert_gate_to_obs(dataset, "CD4_T_cells")
fp.convert_gate_to_obs(dataset, "CD8_T_cells")

# %%
fp.pl.umap(dataset,
           gate = "CD45+",
           layer = "transformed",
           color = "T_cells",
           save = f"{output_dir}t_cells_umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.umap(dataset,
           gate = "CD45+",
           layer = "transformed",
           color = "CD4_T_cells",
           save = f"{output_dir}cd4_t_cells_umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.umap(dataset,
           gate = "CD45+",
           layer = "transformed",
           color = "CD8_T_cells",
           save = f"{output_dir}cd8_t_cells_umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
from matplotlib import pyplot as plt
import seaborn as sns

df = dataset.to_df(layer = "transformed")
df[dataset.obs.columns] = dataset.obs
df[["UMAP1", "UMAP2", "UMAP3"]] = dataset.obsm["X_umap_CD45+_transformed"]

# %%
for col in ["CD3", "CD4", "CD8"]:
    low,high = df[col].quantile([.1,.9])
    df[col] = df[col].clip(low,high)

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 1, figsize = (6,3))
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                hue = "T_cells",
                s = 2,
                ax = ax[0],
                linewidth = 0)
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                s = 2,
                c = df["CD3"],
                ax = ax[1],
                linewidth = 0)
ax[0].set_title("cell assignment")
ax[1].set_title("CD3 expression")
plt.tight_layout()
plt.savefig(f"{output_dir}t_cells_umap_relook.png", bbox_inches = "tight", dpi = 300)
plt.show()

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 1, figsize = (6,3))
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                hue = "CD4_T_cells",
                s = 2,
                ax = ax[0],
                linewidth = 0)
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                s = 2,
                c = df["CD4"],
                ax = ax[1],
                linewidth = 0)
ax[0].set_title("cell assignment")
ax[1].set_title("CD4 expression")
plt.tight_layout()
plt.savefig(f"{output_dir}cd4_t_cells_umap_relook.png", bbox_inches = "tight", dpi = 300)
plt.show()

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 1, figsize = (6,3))
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                hue = "CD8_T_cells",
                s = 2,
                ax = ax[0],
                linewidth = 0)
sns.scatterplot(data = df,
                x = "UMAP1",
                y = "UMAP3",
                s = 2,
                c = df["CD8"],
                ax = ax[1],
                linewidth = 0)
ax[0].set_title("cell assignment")
ax[1].set_title("CD8 expression")
plt.tight_layout()
plt.savefig(f"{output_dir}cd8_t_cells_umap_relook.png", bbox_inches = "tight", dpi = 300)
plt.show()

# %%
fp.settings.default_layer = "transformed"
fp.settings.default_gate = "CD4_T_cells"

# %%
fp.tl.mfi(dataset,
          layer = "compensated")
fp.tl.fop(dataset,
          layer = "compensated")
fp.tl.mfi(dataset)
fp.tl.fop(dataset)

# %%
fp.tl.pca_samplewise(dataset,
                     use_only_fluo = True,
                     exclude = None)
### next, we use the according plotting function to display
fp.pl.pca_samplewise(dataset,
                     color = "organ",
                     save = f"{output_dir}pca_samplewise.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
fp.tl.mds_samplewise(dataset,
                     use_only_fluo = True,
                     exclude = None)
### next, we use the according plotting function to display
fp.pl.mds_samplewise(dataset,
                     color = "organ",
                     save = f"{output_dir}mds_samplewise.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'MDS: The settings where changed, because this avoids a future warning. The settings was normalized_stress and the new value is auto'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
fp.tl.tsne_samplewise(dataset,
                     use_only_fluo = True,
                     exclude = None)
### next, we use the according plotting function to display
fp.pl.tsne_samplewise(dataset,
                     color = "organ",
                     save = f"{output_dir}tsne_samplewise.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:423: DimredSettingModificationWarning: 'TSNE: The settings where changed, because this avoids a value error. The settings was perplexity and the new value is 30'
#   warnings.warn(DimredSettingModificationWarning._construct_message(**warning_kwargs),
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
fp.tl.umap_samplewise(dataset,
                     use_only_fluo = True,
                     exclude = None)
### next, we use the according plotting function to display
fp.pl.umap_samplewise(dataset,
                     color = "organ",
                     save = f"{output_dir}umap_samplewise.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
fp.pl.mfi(dataset,
          groupby = "organ",
          marker = "PD-1_(CD279) ",
          figsize = (2,4),
          save = f"{output_dir}mfi_plot.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.pl.fop(dataset,
          layer = "compensated",
          groupby = "organ",
          marker = "PD-1_(CD279) ",
          figsize = (2,4),
          save = f"{output_dir}fop_plot.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fp.settings.default_gate = "CD45+"
fp.settings.default_layer = "transformed"

# %%
fp.tl.pca(dataset)
fp.tl.neighbors(dataset)
fp.tl.leiden(dataset)
fp.tl.umap(dataset)
fp.tl.tsne(dataset)
fp.tl.diffmap(dataset)

# %%
dataset
# Out:
# AnnData object with n_obs × n_vars = 100000 × 36
#     obs: 'sample_ID', 'file_name', 'group_fd', 'internal_id', 'organ', 'staining', 'diag_main', 'diag_fine', 'donor_id', 'material', 'batch', 'NK_cells', 'T_cells', 'CD4_T_cells', 'CD8_T_cells', 'CD45+_transformed_leiden'
#     var: 'pns', 'png', 'pne', 'type', 'pnn', 'cofactors'
#     uns: 'metadata', 'panel', 'workspace', 'gating_cols', 'dataset_status_hash', 'cofactors', 'raw_cofactors', 'cofactor_table', 'gate_frequencies', 'settings', 'pca_CD45+_transformed', 'CD45+_transformed_neighbors', 'CD45+_transformed_leiden', 'umap_CD45+_transformed', 'CD45+_transformed_leiden_colors', 'NK_cells_colors', 'T_cells_colors', 'CD4_T_cells_colors', 'CD8_T_cells_colors', 'mfi_sample_ID_compensated', 'fop_sample_ID_compensated', 'mfi_sample_ID_transformed', 'fop_sample_ID_transformed', 'tsne_CD45+_transformed', 'CD45+_transformed_diffmap_evals'
#     obsm: 'gating', 'X_pca_CD45+_transformed', 'X_umap_CD45+_transformed', 'X_tsne_CD45+_transformed', 'X_diffmap_CD45+_transformed'
#     varm: 'pca_CD45+_transformed'
#     layers: 'compensated', 'transformed'
#     obsp: 'CD45+_transformed_neighbors_connectivities', 'CD45+_transformed_neighbors_distances'

# %%
dataset.obsm["X_diffmap_CD45+_transformed"] = dataset.obsm["X_diffmap_CD45+_transformed"][:,1:]

# %%
fp.pl.umap(dataset,
           color = "organ",
           save = f"{output_dir}umap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.tsne(dataset,
           color = "organ", 
           save = f"{output_dir}tsne.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.pca(dataset,
          color = "organ",
          save = f"{output_dir}pca.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.diffmap(dataset,
              color = "organ",
              save = f"{output_dir}diffmap.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.tl.parc(dataset)
fp.tl.phenograph(dataset)
fp.tl.flowsom(dataset)
# Out:
# input data has shape 100000 (samples) x 28 (features)
# commencing global pruning
# commencing community detection
# partition type MVP
# list of cluster labels and populations 42 [(0, 9739), (1, 6372), (2, 6019), (3, 5853), (4, 5284), (5, 5198), (6, 5014), (7, 4861), (8, 4363), (9, 3926), (10, 3939), (11, 3916), (12, 3632), (13, 3484), (14, 3125), (15, 2580), (16, 2547), (17, 2234), (18, 2158), (19, 1835), (20, 1611), (21, 1564), (22, 1445), (23, 1387), (24, 1000), (25, 972), (26, 775), (27, 765), (28, 668), (29, 657), (30, 651), (31, 542), (32, 346), (33, 346), (34, 325), (35, 230), (36, 151), (37, 149), (38, 133), (39, 102), (40, 53), (41, 49)]
# time elapsed 5.1 seconds
# warning! Setting k to 30 to avoid errors
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 3.972893476486206 seconds
# Jaccard graph constructed in 5.753772020339966 seconds
# Running Leiden optimization
# Leiden completed in 12.632861614227295 seconds
# Sorting communities by size, please wait ...
# PhenoGraph completed in 26.029059410095215 seconds

# %%
fp.pl.umap(dataset,
           color = "CD45+_transformed_leiden",
           legend_loc = "on data",
           save = f"{output_dir}leiden.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.umap(dataset,
           color = "CD45+_transformed_parc",
           legend_loc = "on data",
           save = f"{output_dir}parc.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.umap(dataset,
           color = "CD45+_transformed_phenograph",
           legend_loc = "on data",
           save = f"{output_dir}phenograph.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.umap(dataset,
           color = "CD45+_transformed_flowsom",
           legend_loc = "on data",
           save = f"{output_dir}flowsom.png")
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fp.pl.expression_heatmap(dataset,
                         metadata_annotation = ["organ", "diag_main", "diag_fine"],
                         marker_annotation = "HLA_DR",
                         figsize = (5,8),
                         save = f"{output_dir}expression_heatmap.png")

# %%
fp.pl.marker_correlation(dataset,
                         figsize = (6,6),
                         y_label_fontsize = 8,
                         save = f"{output_dir}marker_correlation.png")

# %%
fp.pl.sample_correlation(dataset,
                         metadata_annotation = ["organ", "diag_main", "diag_fine"],
                         metaclusters = 2,
                         corr_method = "spearman",
                         label_metaclusters_in_dataset = True,
                         label_metaclusters_key = "sample_corr_metaclusters",
                         save = f"{output_dir}sample_correlation.png")

# %%
fp.pl.sample_distance(dataset,
                      metadata_annotation = ["organ", "diag_main", "diag_fine"],
                      metaclusters = 2,
                      label_metaclusters_in_dataset = True,
                      label_metaclusters_key = "sample_dist_metaclusters",
                         save = f"{output_dir}sample_distance.png")

# %%
fp.pl.fold_change(dataset,
                  layer = "compensated",
                  groupby  = "organ",
                  group1 = "PB",
                  group2 = "organ2",
                  figsize = (2,6),
                  save = f"{output_dir}diffexp.png")
